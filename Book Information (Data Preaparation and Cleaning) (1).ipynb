# %%
import pandas as pd

# %%
excel_url = r'C:\Users\somku\Downloads\ImmverseAI_Task_Dataset .xlsx'

# %%
all_sheets = pd.read_excel(excel_url,sheet_name = None)

# %% [markdown]
# #### Sheet1

# %%
sheet1 = all_sheets['Sheet1']

# %%
sheet1
# Out:
#    sr_number              book_id  \
# 0      33334  IKS_G-Drive_33334\t
# 1      33335  IKS_G-Drive_33335\t
# 2      33336    IKS_G-Drive_33336
# 3      33343    IKS_G-Drive_33343
# 4      33344    IKS_G-Drive_33344
# ..       ...                  ...
# 80       NaN                  NaN
# 81       NaN                  NaN
# 82       NaN                  NaN
# 83       NaN                  NaN
# 84       NaN                  NaN
#
#                                      name_of_the_book  no_of_pages  \
# 0   Dil India Vol. 2 November 2017 - Rashtriya Hin...         32.0
# 1   Dil India Vol. 2 October 2017 - Rashtriya Hind...         32.0
# 2   Kalyan Issue No. 12 Vol. 11 Dec 2017 - Gita Press         52.0
# 3   Kalyan Issue No. 7 Vol. 89 July 2015 - Gita Press         52.0
# 4   Kalyan Issue No. 6 Vol. 89 June 2015 - Gita Press         52.0
# ..                                                ...          ...
# 80                                                NaN          NaN
# ...

# %%
sheet1.shape
# Out:
# (51, 11)

# %%
sheet1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sr. Number          51 non-null     int64
#  1   Book_ID             51 non-null     object
#  2   Name of the Book    51 non-null     object
#  3   No. of pages        51 non-null     int64
#  4   Editor              51 non-null     object
#  5   Name of the Author  51 non-null     object
#  6   Publishers          51 non-null     object
#  7   Year of Publishing  51 non-null     object
#  8   Language            51 non-null     object
#  9   Format              51 non-null     object
#  10  Digitized by        51 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 4.5+ KB

# %%
sheet1['Language'] = sheet1['Language'].astype('string')

# %%
sheet1['Language'].dtype
# Out:
# string[python]

# %%
sheet1['language'].value_counts().head()
# Out:
# language
# Sanskrit             18
# Sanskrit, Hindi      15
# Sanskrit, English     5
# Hindi                 4
# English               4
# Name: count, dtype: int64

# %%
sheet1
# Out:
#     Sr. Number            Book_ID  \
# 0        33334  IKS_G-Drive_33334
# 1        33335  IKS_G-Drive_33335
# 2        33336  IKS_G-Drive_33336
# 3        33343  IKS_G-Drive_33343
# 4        33344  IKS_G-Drive_33344
# 5        33345  IKS_G-Drive_33345
# 6        33348  IKS_G-Drive_33348
# 7        33349  IKS_G-Drive_33349
# 8        33350  IKS_G-Drive_33350
# 9        33360  IKS_G-Drive_33360
# 10       33361  IKS_G-Drive_33361
# 11       33362  IKS_G-Drive_33362
# 12       33363  IKS_G-Drive_33363
# 13       33364  IKS_G-Drive_33364
# 14       33365  IKS_G-Drive_33365
# 15       33366  IKS_G-Drive_33366
# 16       33372  IKS_G-Drive_33372
# 17       33373  IKS_G-Drive_33373
# 18       33374  IKS_G-Drive_33374
# 19       33375  IKS_G-Drive_33375
# 20       33376  IKS_G-Drive_33376
# 21       33377  IKS_G-Drive_33377
# 22       79515  IKS_G-Drive_79515
# 23       79516  IKS_G-Drive_79516
# 24       79517  IKS_G-Drive_79517
# 25       79518  IKS_G-Drive_79518
# ...

# %%
sheet1.isnull().sum()
# Out:
# sr__number            0
# book_id               0
# name_of_the_book      0
# no__of_pages          0
# editor                0
# name_of_the_author    0
# publishers            0
# year_of_publishing    0
# language              0
# format                0
# digitized_by          0
# dtype: int64

# %%
sheet1.describe()
# Out:
#          Sr. Number  No. of pages
# count     51.000000     51.000000
# mean   60411.941176    226.921569
# std    23843.245224    201.720484
# min    33334.000000     32.000000
# 25%    33363.500000     53.500000
# 50%    79518.000000    149.000000
# 75%    79855.000000    323.500000
# max    83842.000000    801.000000

# %%
sheet1.columns = sheet1.columns.str.strip().str.lower()

# %%
sheet1
# Out:
#     sr__number            book_id  \
# 0        33334  IKS_G-Drive_33334
# 1        33335  IKS_G-Drive_33335
# 2        33336  IKS_G-Drive_33336
# 3        33343  IKS_G-Drive_33343
# 4        33344  IKS_G-Drive_33344
# 5        33345  IKS_G-Drive_33345
# 6        33348  IKS_G-Drive_33348
# 7        33349  IKS_G-Drive_33349
# 8        33350  IKS_G-Drive_33350
# 9        33360  IKS_G-Drive_33360
# 10       33361  IKS_G-Drive_33361
# 11       33362  IKS_G-Drive_33362
# 12       33363  IKS_G-Drive_33363
# 13       33364  IKS_G-Drive_33364
# 14       33365  IKS_G-Drive_33365
# 15       33366  IKS_G-Drive_33366
# 16       33372  IKS_G-Drive_33372
# 17       33373  IKS_G-Drive_33373
# 18       33374  IKS_G-Drive_33374
# 19       33375  IKS_G-Drive_33375
# 20       33376  IKS_G-Drive_33376
# 21       33377  IKS_G-Drive_33377
# 22       79515  IKS_G-Drive_79515
# 23       79516  IKS_G-Drive_79516
# 24       79517  IKS_G-Drive_79517
# 25       79518  IKS_G-Drive_79518
# ...

# %%
sheet1 = pd.DataFrame({'language':['Sanakrit,Hindi','Sanskrit,English','Sanskrit,English,Hindi']})
sheet1["language_cleaned"] = sheet1["language"].str.split(',').str[0].str.strip()

# %%
sheet1
# Out:
#                  language language_cleaned
# 0          Sanakrit,Hindi         Sanakrit
# 1        Sanskrit,English         Sanskrit
# 2  Sanskrit,English,Hindi         Sanskrit

# %% [markdown]
# #### Sheet2

# %%
sheet2 = all_sheets['Sheet2']

# %%
sheet2
# Out:
#      Book_ID                                   Name of the Book  \
# 0      YPA_1  Bal Sanskar Aur Iske Vaigyanik Mahatva Ki Sami...
# 1      YPA_2  Pramukh Bhartiya Lokachar Aur Prabandhan Mein ...
# 2      YPA_3      Prachin Bharat Mein Mulya Shiksha Prashikshan
# 3      YPA_4                       A Primer to the Vedic Corpus
# 4      YPA_5               Codification of Law in India, Part 1
# 5      YPA_6               Codification of Law in India, Part 2
# 6      YPA_7            Veer Savarkar: Inside Enemy Camp Part 1
# 7      YPA_8            Veer Savarkar: Inside Enemy Camp Part 2
# 8      YPA_9  Cultural Representation in Media - An Analysis...
# 9     YPA_10  The Months of The Hindu Calendar - Significanc...
# 10    YPA_11  The Months of The Hindu Calendar - Significanc...
# 11    YPA_12  Vasant Panchami - Celebrating Knowledge and Wi...
# 12    YPA_13    Makar Sankranti - The Worship of Bhagavan Surya
# 13    YPA_14                     The Atman in Hinduism - Part 1
# ...

# %%
sheet2.shape
# Out:
# (51, 9)

# %%
sheet2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Book_ID             51 non-null     object
#  1   Name of the Book    51 non-null     object
#  2   Name of the Author  51 non-null     object
#  3   Number of Pages     51 non-null     int64
#  4   Publishers          51 non-null     object
#  5   Year of Publishing  51 non-null     int64
#  6   Language            51 non-null     object
#  7   Format              51 non-null     object
#  8   Source of the data  51 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 3.7+ KB

# %%
sheet2.isnull().sum()
# Out:
# Book_ID               0
# Name of the Book      0
# Name of the Author    0
# Number of Pages       0
# Publishers            0
# Year of Publishing    0
# Language              0
# Format                0
# Source of the data    0
# dtype: int64

# %%
sheet2.describe(include='all')
# Out:
#        Book_ID                                   Name of the Book  \
# count       51                                                 51
# unique      51                                                 51
# top      YPA_1  Bal Sanskar Aur Iske Vaigyanik Mahatva Ki Sami...
# freq         1                                                  1
# mean       NaN                                                NaN
# std        NaN                                                NaN
# min        NaN                                                NaN
# 25%        NaN                                                NaN
# 50%        NaN                                                NaN
# 75%        NaN                                                NaN
# max        NaN                                                NaN
#
#        Name of the Author  Number of Pages      Publishers  \
# count                  51             51.0              51
# ...

# %%
sheet2.describe()
# Out:
#        Number of Pages  Year of Publishing
# count             51.0                51.0
# mean               1.0              2024.0
# std                0.0                 0.0
# min                1.0              2024.0
# 25%                1.0              2024.0
# 50%                1.0              2024.0
# 75%                1.0              2024.0
# max                1.0              2024.0

# %%
sheet2.columns=sheet2.columns.str.strip().str.lower()

# %%
sheet2
# Out:
#      book_id                                   name of the book  \
# 0      YPA_1  Bal Sanskar Aur Iske Vaigyanik Mahatva Ki Sami...
# 1      YPA_2  Pramukh Bhartiya Lokachar Aur Prabandhan Mein ...
# 2      YPA_3      Prachin Bharat Mein Mulya Shiksha Prashikshan
# 3      YPA_4                       A Primer to the Vedic Corpus
# 4      YPA_5               Codification of Law in India, Part 1
# 5      YPA_6               Codification of Law in India, Part 2
# 6      YPA_7            Veer Savarkar: Inside Enemy Camp Part 1
# 7      YPA_8            Veer Savarkar: Inside Enemy Camp Part 2
# 8      YPA_9  Cultural Representation in Media - An Analysis...
# 9     YPA_10  The Months of The Hindu Calendar - Significanc...
# 10    YPA_11  The Months of The Hindu Calendar - Significanc...
# 11    YPA_12  Vasant Panchami - Celebrating Knowledge and Wi...
# 12    YPA_13    Makar Sankranti - The Worship of Bhagavan Surya
# 13    YPA_14                     The Atman in Hinduism - Part 1
# ...

# %%
sheet2['language'].value_counts().head()
# Out:
# language
# Unknown    49
# English     2
# Name: count, dtype: int64

# %% [markdown]
# #### Sheet3

# %%
sheet3 = all_sheets['Sheet3']

# %%
sheet3
# Out:
#                                          Website Link  \
# 0   https://www.ebharatisampat.in/readpdf.php?id=N...
# 1   https://www.ebharatisampat.in/readpdf.php?id=O...
# 2   https://www.ebharatisampat.in/readpdf.php?id=M...
# 3   https://www.ebharatisampat.in/readpdf.php?id=M...
# 4   https://www.ebharatisampat.in/readpdf.php?id=N...
# 5   https://www.ebharatisampat.in/readpdf.php?id=N...
# 6   https://www.ebharatisampat.in/readpdf.php?id=M...
# 7   https://www.ebharatisampat.in/readpdf.php?id=M...
# 8   https://www.ebharatisampat.in/readpdf.php?id=N...
# 9   https://www.ebharatisampat.in/readpdf.php?id=N...
# 10  https://www.ebharatisampat.in/readpdf.php?id=O...
# 11  https://www.ebharatisampat.in/readpdf.php?id=M...
# 12  https://www.ebharatisampat.in/readpdf.php?id=M...
# 13  https://www.ebharatisampat.in/readpdf.php?id=N...
# 14  https://www.ebharatisampat.in/readpdf.php?id=N...
# 15  https://www.ebharatisampat.in/readpdf.php?id=N...
# ...

# %%
sheet3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Website Link        37 non-null     object
#  1   Title               37 non-null     object
#  2   Author              37 non-null     object
#  3   Publisher           37 non-null     object
#  4   Book_ID             37 non-null     object
#  5   Publish Year        37 non-null     object
#  6   Number of Pages     37 non-null     object
#  7   Language            37 non-null     object
#  8   Format              37 non-null     object
#  9   Source of the data  37 non-null     object
# dtypes: object(10)
# memory usage: 3.0+ KB

# %%
sheet3["Number of Pages"]=sheet3["Number of Pages"].astype("Int64")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\integer.py:53, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      52 try:
# ---> 53     return values.astype(dtype, casting="safe", copy=copy)
#      54 except TypeError as err:
#
# TypeError: Cannot cast array data from dtype('O') to dtype('int64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 sheet3["Number of Pages"]=sheet3["Number of Pages"].astype("Int64")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
# ...

# %%
sheet3.shape
# Out:
# (37, 10)

# %%
sheet3.isnull().sum()
# Out:
# Website Link           0
# Title                  0
# Author                 3
# Publisher             12
# Book_ID                0
# Publish Year          11
# Number of Pages        7
# Language               0
# Format                 0
# Source of the data     0
# dtype: int64

# %%
sheet3.fillna("Unknown",inplace=True)

# %%
sheet3
# Out:
#                                          Website Link  \
# 0   https://www.ebharatisampat.in/readpdf.php?id=N...
# 1   https://www.ebharatisampat.in/readpdf.php?id=O...
# 2   https://www.ebharatisampat.in/readpdf.php?id=M...
# 3   https://www.ebharatisampat.in/readpdf.php?id=M...
# 4   https://www.ebharatisampat.in/readpdf.php?id=N...
# 5   https://www.ebharatisampat.in/readpdf.php?id=N...
# 6   https://www.ebharatisampat.in/readpdf.php?id=M...
# 7   https://www.ebharatisampat.in/readpdf.php?id=M...
# 8   https://www.ebharatisampat.in/readpdf.php?id=N...
# 9   https://www.ebharatisampat.in/readpdf.php?id=N...
# 10  https://www.ebharatisampat.in/readpdf.php?id=O...
# 11  https://www.ebharatisampat.in/readpdf.php?id=M...
# 12  https://www.ebharatisampat.in/readpdf.php?id=M...
# 13  https://www.ebharatisampat.in/readpdf.php?id=N...
# 14  https://www.ebharatisampat.in/readpdf.php?id=N...
# 15  https://www.ebharatisampat.in/readpdf.php?id=N...
# ...

# %%
sheet3.isnull().sum()
# Out:
# Website Link          0
# Title                 0
# Author                0
# Publisher             0
# Book_ID               0
# Publish Year          0
# Number of Pages       0
# Language              0
# Format                0
# Source of the data    0
# dtype: int64

# %%
sheet3.columns=sheet3.columns.str.strip().str.lower()

# %%
sheet3
# Out:
#                                          website link  \
# 0   https://www.ebharatisampat.in/readpdf.php?id=N...
# 1   https://www.ebharatisampat.in/readpdf.php?id=O...
# 2   https://www.ebharatisampat.in/readpdf.php?id=M...
# 3   https://www.ebharatisampat.in/readpdf.php?id=M...
# 4   https://www.ebharatisampat.in/readpdf.php?id=N...
# 5   https://www.ebharatisampat.in/readpdf.php?id=N...
# 6   https://www.ebharatisampat.in/readpdf.php?id=M...
# 7   https://www.ebharatisampat.in/readpdf.php?id=M...
# 8   https://www.ebharatisampat.in/readpdf.php?id=N...
# 9   https://www.ebharatisampat.in/readpdf.php?id=N...
# 10  https://www.ebharatisampat.in/readpdf.php?id=O...
# 11  https://www.ebharatisampat.in/readpdf.php?id=M...
# 12  https://www.ebharatisampat.in/readpdf.php?id=M...
# 13  https://www.ebharatisampat.in/readpdf.php?id=N...
# 14  https://www.ebharatisampat.in/readpdf.php?id=N...
# 15  https://www.ebharatisampat.in/readpdf.php?id=N...
# ...

# %%
sheet3['language'].value_counts().head()
# Out:
# language
# Sanskrit              18
# Sanskrit Hindi         9
# sanskrutam aanglam     6
# Sankritamangalam       2
# Sanskritum Anglam      1
# Name: count, dtype: int64

# %% [markdown]
# #### Sheet4

# %%
sheet4=all_sheets['Sheet4']

# %%
sheet4
# Out:
#         book_id                   name_of_the_book  no_of_pages  \
# 0    IKS_HDD_91          ashvlayan shraut sutram 2          458
# 1    IKS_HDD_92            Katyayana Srautasutra 1          567
# 2    IKS_HDD_93            Katyayana Srautasutra 2          483
# 3    IKS_HDD_94         Nighantu nirvachan mimansa          320
# 4    IKS_HDD_95  Vedik sanhitaao me vividh vidhaye          401
# 5    IKS_HDD_96      Indian and Western Philosophy          225
# 6    IKS_HDD_97      Katyayan SHraut Sutram Part 1          636
# 7    IKS_HDD_98      Katyayan SHraut Sutram Part 2          795
# 8    IKS_HDD_99      Katyayan SHraut Sutram Part 3          402
# 9   IKS_HDD_100              Katyayan Shulva Sutra          252
# 10  IKS_HDD_101              PRAYAGRAJ KUMBH KATHA          150
# 11  IKS_HDD_102  Shree Bagavatgeta ek wyvharshasrt          292
#
#         name_of_the_author                                         publishers  \
# ...

# %%
sheet4.shape
# Out:
# (12, 9)

# %%
sheet4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Book_ID             12 non-null     object
#  1   Name of the Book    12 non-null     object
#  2   No. of pages        12 non-null     int64
#  3   Name of the Author  12 non-null     object
#  4   Publishers          12 non-null     object
#  5   Year of Publishing  12 non-null     int64
#  6   Language            12 non-null     object
#  7   Format              12 non-null     object
#  8   Source of the data  12 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 996.0+ bytes

# %%
sheet4.isnull().sum()
# Out:
# Book_ID               0
# Name of the Book      0
# No. of pages          0
# Name of the Author    0
# Publishers            0
# Year of Publishing    0
# Language              0
# Format                0
# Source of the data    0
# dtype: int64

# %%
sheet4.describe()
# Out:
#        No. of pages  Year of Publishing
# count     12.000000           12.000000
# mean     415.083333         2009.833333
# std      185.920539            9.824213
# min      150.000000         1990.000000
# 25%      282.000000         2006.000000
# 50%      401.500000         2012.000000
# 75%      504.000000         2016.000000
# max      795.000000         2020.000000

# %%
sheet4.columns=sheet4.columns.str.strip().str.lower()

# %%
sheet4
# Out:
#         book_id                   name of the book  no. of pages  \
# 0    IKS_HDD_91          ashvlayan shraut sutram 2           458
# 1    IKS_HDD_92            Katyayana Srautasutra 1           567
# 2    IKS_HDD_93            Katyayana Srautasutra 2           483
# 3    IKS_HDD_94         Nighantu nirvachan mimansa           320
# 4    IKS_HDD_95  Vedik sanhitaao me vividh vidhaye           401
# 5    IKS_HDD_96      Indian and Western Philosophy           225
# 6    IKS_HDD_97      Katyayan SHraut Sutram Part 1           636
# 7    IKS_HDD_98      Katyayan SHraut Sutram Part 2           795
# 8    IKS_HDD_99      Katyayan SHraut Sutram Part 3           402
# 9   IKS_HDD_100              Katyayan Shulva Sutra           252
# 10  IKS_HDD_101              PRAYAGRAJ KUMBH KATHA           150
# 11  IKS_HDD_102  Shree Bagavatgeta ek wyvharshasrt           292
#
#         name of the author                                         publishers  \
# ...

# %%
sheet4['language'].value_counts().head()
# Out:
# language
# Sanskrit, Hindi      9
# Sanskrit, English    3
# Name: count, dtype: int64

# %%
sheet4 = pd.DataFrame({'language':['Sanakrit,Hindi','Sanskrit,English',]})
sheet4["language_cleaned"] = sheet1["language"].str.split(',').str[0].str.strip()

# %%
sheet4
# Out:
#            language language_cleaned
# 0    Sanakrit,Hindi         Sanakrit
# 1  Sanskrit,English         Sanskrit
